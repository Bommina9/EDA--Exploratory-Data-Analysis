# %% [markdown]
# <a href="https://colab.research.google.com/github/Bommina9/EDA--Exploratory-Data-Analysis/blob/main/1_EDA_asGroup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA: Group Assignment #1

# %% [markdown]
# ------------------------------------
# **Dr. Dave Wanik - OPIM 5512: Data Science Using Python - University of Connecticut**
#
# -----------------------------

# %% [markdown]
# Your Name Here:Hemanth Sai Kumar Bommina
#
# Groups of four students - give feedback to at least one other person (everyone must receive feedback). First come, first serve!

# %% [markdown]
# The purpose of this assignment is to get you working with the two most common visualization libraries in Python, `matplotlib` (plt) and `seaborn` (sns).
#
# # Rubric
# * Each student will decide to use `matplotlib` or `seabron` or both.
# * (10 pts) Find **FOUR** interesting examples blogs/websites where an EDA is completed with `matplotlib` or `sns`. List and describe the five sources that you used in a subheader with a short description of the website.
# * (30 pts) Each student will use the dataset that is given to create **FOUR** interesting plots using their respective library (`matplotlib` or `sns`). Each figure must have a useful caption with a description of what the table is and what insights can be derived from the plot.
# * (30 pts) Each student will create **FOUR** unique tables using pandas. Each table must have a useful caption with a description of what the table is and what insights can be derived from the table.
# * (20 pts) Students will post to HuskyCT forum for peer review - thoughtful comments must be given (what was good, what could be improved, something new that could be added.)
# * After posting their script for review for peer feedback (as both as shareable link viewable to anyone with the link and as an uploaded file to HuskyCT), students will compare each others code quality and captions (business value of plot and table) and make a suggestions for improvement.
#
# ## Examples of common feedback items on HuskyCT
# * "I like how you tried four different plots instead of just using one plot over and over again"
# * "Your caption for Figure 2 could be more clear - maybe say something like this..."
# * "I think it would be interesting to redo Table 3 but group by variable X instead of Z, that way you could get a better understanding of..."
# * "I think you could have made a more thougtful caption for Figure 1 - what is the real value of the plot?"

# %% [markdown]
# # Sources
# Here is an example of a good source:
# * [How to Perform Exploratory Data Analysis with Seaborn - Lorraine Lee](https://towardsdatascience.com/how-to-perform-exploratory-data-analysis-with-seaborn-97e3413e841d)
#   * This article was useful because it had a thorough presentation on making plots for categorical and numeric data in seaborn and had lots of 'hackable' code for making subplots.

# %% [markdown]
# # Read the data
# To keep things consistent in our May term class, we will often use this California Housing dataset that's a part of Colab.

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head(n=5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.tail(n=5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
df[0:10]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df= df[0:10]

# %%
df
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           10 non-null     float64
#  1   latitude            10 non-null     float64
#  2   housing_median_age  10 non-null     float64
#  3   total_rooms         10 non-null     float64
#  4   total_bedrooms      10 non-null     float64
#  5   population          10 non-null     float64
#  6   households          10 non-null     float64
#  7   median_income       10 non-null     float64
#  8   median_house_value  10 non-null     float64
# dtypes: float64(9)
# memory usage: 848.0 bytes

# %%
df.describe()
# Out:
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# count   10.000000  10.000000           10.000000    10.000000       10.000000
# mean  -114.542000  34.000000           26.000000  2832.900000      658.900000
# std      0.089294   0.519145           11.205158  2377.174534      595.440537
# min   -114.600000  33.570000           14.000000   720.000000      168.000000
# 25%   -114.587500  33.615000           17.500000  1403.750000      254.250000
# 50%   -114.575000  33.665000           22.500000  1499.000000      331.500000
# 75%   -114.562500  34.347500           32.750000  4318.500000     1051.250000
# max   -114.310000  34.830000           46.000000  7650.000000     1901.000000
#
#         population   households  median_income  median_house_value
# count    10.000000    10.000000      10.000000           10.000000
# mean   1042.400000   389.700000       2.217910        68300.000000
# ...

# %%
# Import Library
import numpy as np

# %%
print(df.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# Using numpy for calculating mean and median

# %%
np.mean(df['housing_median_age'])
# Out:
# 26.0

# %%
np.median(df['housing_median_age'])
# Out:
# 22.5

# %% [markdown]
# # Plots
# Plots should be labeled with subheaders and have a useful caption that describes what is being shown in the plot.

# %% [markdown]
# Import Matplotlib fro Plots visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['housing_median_age'])
plt.ylabel('housing_median_age')
plt.title('Boxplot of Median housing age')
plt.show()

# %%
df['housing_median_age'].quantile([0.25]) # orange line on the box plot
# Out:
# 0.25    17.5
# Name: housing_median_age, dtype: float64

# %%
df['housing_median_age'].quantile([0.25,0.50,0.75])
# Out:
# 0.25    17.50
# 0.50    22.50
# 0.75    32.75
# Name: housing_median_age, dtype: float64

# %% [markdown]
# Min and Max Function

# %%
np.min(df['housing_median_age'])
# Out:
# 14.0

# %%
np.max(df['housing_median_age'])
# Out:
# 46.0

# %% [markdown]
# subsetting (slicing) Data

# %%
df
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
# select rows using their position
# select rows 0 through 2 (3 in total)
# [start: up to but not including]
tmp = df[0:3]
tmp
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0

# %%
# select rows based on condition
tmp = df[df['housing_median_age']>22]
tmp
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 5       671.0       239.0         3.3438             74000.0
# 6      1841.0       633.0         2.6768             82400.0
# 7       375.0       158.0         1.7083             48500.0
# 8      3134.0      1056.0         2.1782             58400.0
# 9       787.0       271.0         2.1908             48100.0

# %% [markdown]
# Selecting Columns

# %%
tmp = df[['housing_median_age', 'total_rooms']]
tmp
# Out:
#    housing_median_age  total_rooms
# 0                15.0       5612.0
# 1                19.0       7650.0
# 2                17.0        720.0
# 3                14.0       1501.0
# 4                20.0       1454.0
# 5                29.0       1387.0
# 6                25.0       2907.0
# 7                41.0        812.0
# 8                34.0       4789.0
# 9                46.0       1497.0

# %%
tmp = df.loc[:,'housing_median_age':'total_bedrooms']
tmp
# Out:
#    housing_median_age  total_rooms  total_bedrooms
# 0                15.0       5612.0          1283.0
# 1                19.0       7650.0          1901.0
# 2                17.0        720.0           174.0
# 3                14.0       1501.0           337.0
# 4                20.0       1454.0           326.0
# 5                29.0       1387.0           236.0
# 6                25.0       2907.0           680.0
# 7                41.0        812.0           168.0
# 8                34.0       4789.0          1175.0
# 9                46.0       1497.0           309.0

# %%
tmp = df.loc[:,['housing_median_age','total_rooms','total_bedrooms']]
tmp
# Out:
#    housing_median_age  total_rooms  total_bedrooms
# 0                15.0       5612.0          1283.0
# 1                19.0       7650.0          1901.0
# 2                17.0        720.0           174.0
# 3                14.0       1501.0           337.0
# 4                20.0       1454.0           326.0
# 5                29.0       1387.0           236.0
# 6                25.0       2907.0           680.0
# 7                41.0        812.0           168.0
# 8                34.0       4789.0          1175.0
# 9                46.0       1497.0           309.0

# %% [markdown]
# with Iloc()

# %%
tmp= df.iloc[:,2:4]
tmp
# Out:
#    housing_median_age  total_rooms
# 0                15.0       5612.0
# 1                19.0       7650.0
# 2                17.0        720.0
# 3                14.0       1501.0
# 4                20.0       1454.0
# 5                29.0       1387.0
# 6                25.0       2907.0
# 7                41.0        812.0
# 8                34.0       4789.0
# 9                46.0       1497.0

# %%
tmp = df.iloc[:,[5,2,3,4]]
tmp
# Out:
#    population  housing_median_age  total_rooms  total_bedrooms
# 0      1015.0                15.0       5612.0          1283.0
# 1      1129.0                19.0       7650.0          1901.0
# 2       333.0                17.0        720.0           174.0
# 3       515.0                14.0       1501.0           337.0
# 4       624.0                20.0       1454.0           326.0
# 5       671.0                29.0       1387.0           236.0
# 6      1841.0                25.0       2907.0           680.0
# 7       375.0                41.0        812.0           168.0
# 8      3134.0                34.0       4789.0          1175.0
# 9       787.0                46.0       1497.0           309.0

# %% [markdown]
# Selecting rows and columns

# %%
tmp = df.iloc[[1,2,3,4] , [2,3,4]]
tmp
# Out:
#    housing_median_age  total_rooms  total_bedrooms
# 1                19.0       7650.0          1901.0
# 2                17.0        720.0           174.0
# 3                14.0       1501.0           337.0
# 4                20.0       1454.0           326.0

# %%
# selecting rows based on condition
tmp= df[df['housing_median_age']>20]

# %%
tmp = df[df['population']<=1000]

# %%
 tmp = df[(df['population']<=1000) & (df['housing_median_age']>20)]
 tmp
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5    -114.58     33.63                29.0       1387.0           236.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 5       671.0       239.0         3.3438             74000.0
# 7       375.0       158.0         1.7083             48500.0
# 9       787.0       271.0         2.1908             48100.0

# %%
df['MyNewcolumn']=99
df
# Out:
# <ipython-input-82-5b63cd771353>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MyNewcolumn']=99
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# ...

# %% [markdown]
# # Grouping a column

# %%
df['Flag_housing_median_age']=np.where(df['housing_median_age']>20,
                                       1, # if true
                                       0 ) #if false
# Out:
# <ipython-input-84-13b4664c6185>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Flag_housing_median_age']=np.where(df['housing_median_age']>20,

# %%
df
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value  Mynewcolumn  \
# 0      1015.0       472.0         1.4936             66900.0           99
# ...

# %% [markdown]
# # Tables
# Tables should be labeled with subheaders and have a useful caption for what is shown in the table.

# %%
# good luck!
